# %% [markdown]
# <a href="https://colab.research.google.com/github/makari09/app_project/blob/main/sample_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# load data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/sakila.csv")
df
# Out:
#        rental_id          rental_date          return_date customer_lastname  \
# 0              1  2005-05-24 22:53:30  2005-05-26 22:04:30            HUNTER
# 1              2  2005-05-24 22:54:33  2005-05-28 19:40:33           COLLAZO
# 2              3  2005-05-24 23:03:39  2005-06-01 22:12:39           MURRELL
# 3              4  2005-05-24 23:04:41  2005-06-03 01:43:41             PURDY
# 4              5  2005-05-24 23:05:21  2005-06-02 04:33:21            HANSEN
# ...          ...                  ...                  ...               ...
# 16039      16045  2005-08-23 22:25:26  2005-08-25 23:54:26             WHITE
# 16040      16046  2005-08-23 22:26:47  2005-08-27 18:02:47             KELLY
# 16041      16047  2005-08-23 22:42:48  2005-08-25 02:48:48             ELLIS
# 16042      16048  2005-08-23 22:43:07  2005-08-31 21:33:07          HAMILTON
# 16043      16049  2005-08-23 22:50:12  2005-08-30 01:01:12            CAUSEY
#
# ...

# %% [markdown]
# discver data !

# %%
df.head()  #first rows
# Out:
#    rental_id          rental_date          return_date customer_lastname  \
# 0          1  2005-05-24 22:53:30  2005-05-26 22:04:30            HUNTER
# 1          2  2005-05-24 22:54:33  2005-05-28 19:40:33           COLLAZO
# 2          3  2005-05-24 23:03:39  2005-06-01 22:12:39           MURRELL
# 3          4  2005-05-24 23:04:41  2005-06-03 01:43:41             PURDY
# 4          5  2005-05-24 23:05:21  2005-06-02 04:33:21            HANSEN
#
#    store_id rental_store_city       film_title  film_rental_duration  \
# 0         1        Lethbridge  BLANKET BEVERLY                     7
# 1         2         Woodridge     FREAKY POCUS                     7
# 2         2         Woodridge    GRADUATE LORD                     7
# 3         1        Lethbridge    LOVE SUICIDES                     6
# 4         2         Woodridge  IDOLS SNATCHERS                     5
#
#    film_rental_rate  film_replacement_cost film_rating
# 0              2.99                  21.99           G
# ...

# %%
df.tail() #last rows
# Out:
#        rental_id          rental_date          return_date customer_lastname  \
# 16039      16045  2005-08-23 22:25:26  2005-08-25 23:54:26             WHITE
# 16040      16046  2005-08-23 22:26:47  2005-08-27 18:02:47             KELLY
# 16041      16047  2005-08-23 22:42:48  2005-08-25 02:48:48             ELLIS
# 16042      16048  2005-08-23 22:43:07  2005-08-31 21:33:07          HAMILTON
# 16043      16049  2005-08-23 22:50:12  2005-08-30 01:01:12            CAUSEY
#
#        store_id rental_store_city            film_title  film_rental_duration  \
# 16039         1        Lethbridge     COMANCHEROS ENEMY                     5
# 16040         2         Woodridge        VOYAGE LEGALLY                     6
# 16041         2         Woodridge       ILLUSION AMELIE                     4
# 16042         1        Lethbridge  HUNCHBACK IMPOSSIBLE                     4
# 16043         2         Woodridge            MOB DUFFEL                     4
#
# ...

# %%
df.shape
# Out:
# (16044, 11)

# %%
df.info()  #KNOW the type find null or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16044 entries, 0 to 16043
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   rental_id              16044 non-null  int64
#  1   rental_date            16044 non-null  object
#  2   return_date            15861 non-null  object
#  3   customer_lastname      16044 non-null  object
#  4   store_id               16044 non-null  int64
#  5   rental_store_city      16044 non-null  object
#  6   film_title             16044 non-null  object
#  7   film_rental_duration   16044 non-null  int64
#  8   film_rental_rate       16044 non-null  float64
#  9   film_replacement_cost  16044 non-null  float64
#  10  film_rating            16044 non-null  object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#           rental_id      store_id  film_rental_duration  film_rental_rate  \
# count  16044.000000  16044.000000           16044.00000      16044.000000
# mean    8025.371478      1.506171               4.93549          2.942630
# std     4632.777249      0.499978               1.40169          1.649678
# min        1.000000      1.000000               3.00000          0.990000
# 25%     4013.750000      1.000000               4.00000          0.990000
# 50%     8025.500000      2.000000               5.00000          2.990000
# 75%    12037.250000      2.000000               6.00000          4.990000
# max    16049.000000      2.000000               7.00000          4.990000
#
#        film_replacement_cost
# count           16044.000000
# mean               20.215443
# std                 6.081771
# min                 9.990000
# 25%                14.990000
# 50%                20.990000
# 75%                25.990000
# max                29.990000

# %% [markdown]
# cleaning

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#        rental_id          rental_date          return_date customer_lastname  \
# 0              1  2005-05-24 22:53:30  2005-05-26 22:04:30            HUNTER
# 1              2  2005-05-24 22:54:33  2005-05-28 19:40:33           COLLAZO
# 2              3  2005-05-24 23:03:39  2005-06-01 22:12:39           MURRELL
# 3              4  2005-05-24 23:04:41  2005-06-03 01:43:41             PURDY
# 4              5  2005-05-24 23:05:21  2005-06-02 04:33:21            HANSEN
# ...          ...                  ...                  ...               ...
# 16039      16045  2005-08-23 22:25:26  2005-08-25 23:54:26             WHITE
# 16040      16046  2005-08-23 22:26:47  2005-08-27 18:02:47             KELLY
# 16041      16047  2005-08-23 22:42:48  2005-08-25 02:48:48             ELLIS
# 16042      16048  2005-08-23 22:43:07  2005-08-31 21:33:07          HAMILTON
# 16043      16049  2005-08-23 22:50:12  2005-08-30 01:01:12            CAUSEY
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15861 entries, 0 to 16043
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   rental_id              15861 non-null  int64
#  1   rental_date            15861 non-null  object
#  2   return_date            15861 non-null  object
#  3   customer_lastname      15861 non-null  object
#  4   store_id               15861 non-null  int64
#  5   rental_store_city      15861 non-null  object
#  6   film_title             15861 non-null  object
#  7   film_rental_duration   15861 non-null  int64
#  8   film_rental_rate       15861 non-null  float64
#  9   film_replacement_cost  15861 non-null  float64
#  10  film_rating            15861 non-null  object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 2.0+ MB

# %%
df['film_rental_rate'].describe()   # take a look on each column
# Out:
# count    15861.000000
# mean         2.944101
# std          1.649766
# min          0.990000
# 25%          0.990000
# 50%          2.990000
# 75%          4.990000
# max          4.990000
# Name: film_rental_rate, dtype: float64

# %%
df['film_rental_rate'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
ax =df['film_rental_rate'].value_counts().plot(kind='bar',figsize=(14,6))
ax.set_ylabel('number of rentails')
# Out:
# Text(0, 0.5, 'number of rentails')

# %%
df['rental_store_city'].value_counts().plot(kind='pie',figsize=(4,12))
# Out:
# <Axes: ylabel='rental_store_city'>

# %%
df['rental_gain_return'] = df['film_rental_rate'] / df['film_replacement_cost'] * 100

# %%
df['rental_gain_return'].head()
# Out:
# 0    13.597090
# 1    17.598587
# 2    19.946631
# 3     4.502046
# 4     9.969990
# Name: rental_gain_return, dtype: float64

# %%
df['rental_gain_return'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df['rental_gain_return'].mean().round(3) #round to minmize the number
# Out:
# 16.346

# %%
m = df['rental_gain_return'].plot(kind='density')
m.axvline(df['rental_gain_return'].mean().round(3),color='red')

# %%
df['rental_gain_return'].median().round(3)
# Out:
# 13.597

# %%
ax = df['rental_gain_return'].plot(kind='density')

# %%
df
# Out:
#        rental_id          rental_date          return_date customer_lastname  \
# 0              1  2005-05-24 22:53:30  2005-05-26 22:04:30            HUNTER
# 1              2  2005-05-24 22:54:33  2005-05-28 19:40:33           COLLAZO
# 2              3  2005-05-24 23:03:39  2005-06-01 22:12:39           MURRELL
# 3              4  2005-05-24 23:04:41  2005-06-03 01:43:41             PURDY
# 4              5  2005-05-24 23:05:21  2005-06-02 04:33:21            HANSEN
# ...          ...                  ...                  ...               ...
# 16039      16045  2005-08-23 22:25:26  2005-08-25 23:54:26             WHITE
# 16040      16046  2005-08-23 22:26:47  2005-08-27 18:02:47             KELLY
# 16041      16047  2005-08-23 22:42:48  2005-08-25 02:48:48             ELLIS
# 16042      16048  2005-08-23 22:43:07  2005-08-31 21:33:07          HAMILTON
# 16043      16049  2005-08-23 22:50:12  2005-08-30 01:01:12            CAUSEY
#
# ...

# %%
  df.loc[df['customer_lastname'] == 'HUNTER']  #to choose specific one put loc and move on
# Out:
#        rental_id          rental_date          return_date customer_lastname  \
# 0              1  2005-05-24 22:53:30  2005-05-26 22:04:30            HUNTER
# 744          746  2005-05-29 09:25:10  2005-06-02 04:20:10            HUNTER
# 1628        1630  2005-06-16 07:55:01  2005-06-19 06:38:01            HUNTER
# 1862        1864  2005-06-17 01:39:47  2005-06-24 19:39:47            HUNTER
# 2161        2163  2005-06-17 23:46:16  2005-06-22 22:48:16            HUNTER
# 2289        2292  2005-06-18 07:37:48  2005-06-20 02:45:48            HUNTER
# 2532        2535  2005-06-19 01:39:04  2005-06-28 01:33:04            HUNTER
# 2979        2982  2005-06-20 08:38:29  2005-06-28 13:21:29            HUNTER
# 4336        4339  2005-07-07 18:41:42  2005-07-08 13:00:42            HUNTER
# 4482        4485  2005-07-08 01:07:54  2005-07-16 03:19:54            HUNTER
# 6350        6353  2005-07-11 20:48:56  2005-07-21 00:11:56            HUNTER
# ...

# %%
df['film_replacement_cost'].max()
# Out:
# 29.99

# %%
  df.loc[df['film_replacement_cost'] == df['film_replacement_cost'].max(), 'film_title'].unique()
# Out:
# array(['IDOLS SNATCHERS', 'LAWLESS VISION', 'SONG HEDWIG',
#        'LOATHING LEGALLY', 'PATIENT SISTER', 'RESERVOIR ADAPTATION',
#        'JEEPERS WEDDING', 'GOLDFINGER SENSIBILITY', 'CHARIOTS CONSPIRACY',
#        'HONEY TIES', 'GRAFFITI LOVE', 'SLACKER LIAISONS', 'DIRTY ACE',
#        'BLINDNESS GUN', 'WYOMING STORM', 'FEUD FROGMEN', 'SALUTE APOLLO',
#        'JINGLE SAGEBRUSH', 'HILLS NEIGHBORS', 'UNCUT SUICIDES',
#        'EVERYONE CRAFT', 'FLATLINERS KILLER', 'BALLROOM MOCKINGBIRD',
#        'RIVER OUTLAW', 'ARABIA DOGMA', 'VIRGIN DAISY', 'JERICHO MULAN',
#        'SASSY PACKER', 'TRACY CIDER', 'LOVER TRUMAN', 'DOCTOR GRAIL',
#        'GILMORE BOILED', 'PRINCESS GIANT', 'CRUELTY UNFORGIVEN',
#        'REIGN GENTLEMEN', 'WEST LION', 'BONNIE HOLOCAUST', 'EARTH VISION',
#        'RANDOM GO', 'CLOCKWORK PARADISE', 'FANTASIA PARK', 'RIGHT CRANES',
#        'CUPBOARD SINNERS', 'OSCAR GOLD', 'SMILE EARRING',
#        'HOLLYWOOD ANONYMOUS', 'POSEIDON FOREVER',
# ...
